# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree

# %%
autos = pd.read_csv('autosML2023.csv')

# %%
autos
# Out:
#                                                      Auto   Año Kilometros  \
# 0                               Fiat Cronos 1.3 Drive Cvt  2023       0 Km
# 1                               Fiat Cronos 1.3 Drive Cvt  2023       0 Km
# 2                               Fiat Cronos 1.3 Drive Cvt  2023       0 Km
# 3                                Fiat Cronos 1.3 Drive Mt  2023       0 Km
# 4                 Renault Alaskan 2.3t 16v Confort Mt 4x2  2023       0 Km
# ...                                                   ...   ...        ...
# 106634  Volkswagen Amarok 2.0 Cd Tdi 180cv Comfortline At  2023       0 Km
# 106635                    Toyota Yaris 1.5 107cv Xls Pack  2023       0 Km
# 106636  Lamborghini Huracán Evo Spyder Huracán Evo Spyder  2021   3.000 Km
# 106637                     Ford Ranger 2.3 Cs F-truck 4x2  2008   5.000 Km
# 106638                      Fiat Cronos 1.3 Precision Cvt  2023       0 Km
#
#              Precio Moneda                                                URL
# 0           510.000      $  https://auto.mercadolibre.com.ar/MLA-139577693...
# 1           450.000      $  https://auto.mercadolibre.com.ar/MLA-139560845...
# 2           350.000      $  https://auto.mercadolibre.com.ar/MLA-156229490...
# 3           480.000      $  https://auto.mercadolibre.com.ar/MLA-139471630...
# 4           400.000      $  https://auto.mercadolibre.com.ar/MLA-146794245...
# ...             ...    ...                                                ...
# 106634  201.000.000      $  https://auto.mercadolibre.com.ar/MLA-139438614...
# 106635  201.000.000      $  https://auto.mercadolibre.com.ar/MLA-136949933...
# 106636      710.000    U$S  https://auto.mercadolibre.com.ar/MLA-155600699...
# 106637  250.000.000      $  https://auto.mercadolibre.com.ar/MLA-155604834...
# 106638      828.100      $  https://auto.mercadolibre.com.ar/MLA-150581209...
#
# [106639 rows x 6 columns]

# %%
# Creo 2 columnas nuevas para separar la marca y el modelo
autos[['Marca', 'Modelo']] = autos['Auto'].str.split(n=2, expand=True)[[0, 1]]

# %%
# Creo una columna nueva para separar el motor
autos['Motor'] = autos['Auto'].str.extract(r'(\d+\.\d+)')

# %%
# Creo una columna nueva para separar la potencia (cv)
autos['Potencia'] = autos['Auto'].str.extract(r'(\d+)cv')

# %%
# Eliminamos el modelo de la columna Auto, ya que tenemos esa informacion en la columna Modelo
autos['Auto'] = autos.apply(lambda row: row['Auto'].replace(row['Modelo'], '').strip(), axis=1)

# %%
# Modificamos el tipo de dato
autos['Motor'] = autos['Motor'].astype('str')
autos['Potencia'] = autos['Potencia'].astype('str')

# %%
autos
# Out:
#                                                Auto   Año Kilometros  \
# 0                               Fiat  1.3 Drive Cvt  2023       0 Km
# 1                               Fiat  1.3 Drive Cvt  2023       0 Km
# 2                               Fiat  1.3 Drive Cvt  2023       0 Km
# 3                                Fiat  1.3 Drive Mt  2023       0 Km
# 4                  Renault  2.3t 16v Confort Mt 4x2  2023       0 Km
# ...                                             ...   ...        ...
# 106634  Volkswagen  2.0 Cd Tdi 180cv Comfortline At  2023       0 Km
# 106635                   Toyota  1.5 107cv Xls Pack  2023       0 Km
# 106636          Lamborghini  Evo Spyder  Evo Spyder  2021   3.000 Km
# 106637                     Ford  2.3 Cs F-truck 4x2  2008   5.000 Km
# 106638                      Fiat  1.3 Precision Cvt  2023       0 Km
#
#              Precio Moneda                                                URL  \
# 0           510.000      $  https://auto.mercadolibre.com.ar/MLA-139577693...
# 1           450.000      $  https://auto.mercadolibre.com.ar/MLA-139560845...
# 2           350.000      $  https://auto.mercadolibre.com.ar/MLA-156229490...
# 3           480.000      $  https://auto.mercadolibre.com.ar/MLA-139471630...
# 4           400.000      $  https://auto.mercadolibre.com.ar/MLA-146794245...
# ...             ...    ...                                                ...
# 106634  201.000.000      $  https://auto.mercadolibre.com.ar/MLA-139438614...
# 106635  201.000.000      $  https://auto.mercadolibre.com.ar/MLA-136949933...
# 106636      710.000    U$S  https://auto.mercadolibre.com.ar/MLA-155600699...
# 106637  250.000.000      $  https://auto.mercadolibre.com.ar/MLA-155604834...
# 106638      828.100      $  https://auto.mercadolibre.com.ar/MLA-150581209...
#
#               Marca   Modelo Motor Potencia
# 0              Fiat   Cronos   1.3      nan
# 1              Fiat   Cronos   1.3      nan
# 2              Fiat   Cronos   1.3      nan
# 3              Fiat   Cronos   1.3      nan
# 4           Renault  Alaskan   2.3      nan
# ...             ...      ...   ...      ...
# 106634   Volkswagen   Amarok   2.0      180
# 106635       Toyota    Yaris   1.5      107
# 106636  Lamborghini  Huracán   nan      nan
# 106637         Ford   Ranger   2.3      nan
# 106638         Fiat   Cronos   1.3      nan
#
# [106639 rows x 10 columns]

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106639 entries, 0 to 106638
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Auto        106639 non-null  object
#  1   Año         106639 non-null  int64
#  2   Kilometros  106639 non-null  object
#  3   Precio      106639 non-null  object
#  4   Moneda      106639 non-null  object
#  5   URL         106639 non-null  object
#  6   Marca       106639 non-null  object
#  7   Modelo      106639 non-null  object
#  8   Motor       106639 non-null  object
#  9   Potencia    106639 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 8.1+ MB

# %%
# Eliminamos el motor y la potencia de la columna Auto ya que tenemos esa informacion en sus respectivas columnas
autos['Auto'] = autos.apply(lambda row: row['Auto'].replace(row['Motor'], '').strip(), axis=1)
autos['Auto'] = autos.apply(lambda row: row['Auto'].replace(row['Potencia'], '').strip(), axis=1)

# %%
# Renombramos la columna Auto a Verision.
autos = autos.rename(columns={'Auto': 'Version'})

# %%
autos.shape
# Out:
# (106639, 10)

# %%
# Reemplazamos los nan de aquellas potencias y motores de los autos que no se pudieron obtener por 0.
autos['Potencia'] = autos['Potencia'].replace('nan', 0)
autos['Motor'] = autos['Motor'].replace('nan', 0)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
# Filtramos el df por algunas palabras que pueden aparecer en Marca, Modelo o Version las cuales puede sesgar nuestro modelo a futuro.

autos = autos[~autos['Marca'].isin(['Baja', 'Compro', 'Vendo', 'Compra', 'Venta', 'Auto', 'Autos', 'Repuesto', 'Repuestos', 'Chapa', 'Compramos', 'Planes', 'Plan'])]
autos = autos[~autos['Modelo'].isin(['Baja', 'Compro', 'Vendo', 'Compra', 'Venta', 'Auto', 'Autos', 'Repuesto', 'Repuestos', 'Chapa', 'Compramos', 'Planes', 'Plan'])]
autos = autos[~autos['Version'].isin(['Baja', 'Compro','Vendo', 'Compra', 'Venta', 'Auto', 'Autos', 'Repuesto', 'Repuestos', 'Chapa', 'Compramos', 'Planes', 'Plan'])]

# %%
autos.shape
# Out:
# (106626, 10)

# %% [markdown]
# Se inicia un proceso para filtrar las versiones de cada auto por cada marca. Con esto se logra que cada version corresponda a la marca y no a otra, para dar un ejemplo

# %%
marcas = autos['Marca'].unique().tolist() # Nos traemos todas las marcas unicas del df.

lista_versiones = []

#Realizamos un bucle for en el cual itere por cada marca reemplazando la marca de la URL y mediante Web Scraping nos traiga las versiones de los autos de cada marca y los almacene en una lista.

for marca in marcas:
    r = requests.get(f'https://autos.mercadolibre.com.ar/{marca}/_FiltersAvailableSidebar?filter=SHORT_VERSION')
    soup = BeautifulSoup(r.content, 'html.parser')
    dom = etree.HTML(str(soup))
    versiones = dom.xpath('//div[@class="ui-search-search-modal-grid-columns"]//span')
    versiones = [f'{marca} {v.text}' for v in versiones]
    lista_versiones.extend(versiones)

# %%
def reemplazar_version(version):
    for v in lista_versiones:
        if v.lower() in version.lower():
            return v
    return version

# Aplicar la función a la columna 'Versión'
autos['Version'] = autos['Version'].apply(lambda x: reemplazar_version(x))

# %%
autos['Version'] = autos.apply(lambda row: row['Version'].replace(row['Marca'], '').strip(), axis=1)

# %%
autos.tail(100)
# Out:
#                          Version   Año  Kilometros       Precio Moneda  \
# 106539                     Sport  2017    1.111 Km  100.000.000      $
# 106540   Cd Tdi cv 4x2 Startline  2023  100.000 Km   99.999.999      $
# 106541                   Sedan X  2020    1.000 Km  100.000.000      $
# 106542           Allure Plus Hdi  2018   26.000 Km   99.999.999      $
# 106543              Hdi Sv Sport  2010  138.000 Km   99.999.999      $
# ...                          ...   ...         ...          ...    ...
# 106634  Cd Tdi cv Comfortline At  2023        0 Km  201.000.000      $
# 106635               cv Xls Pack  2023        0 Km  201.000.000      $
# 106636    Evo Spyder  Evo Spyder  2021    3.000 Km      710.000    U$S
# 106637            Cs F-truck 4x2  2008    5.000 Km  250.000.000      $
# 106638             Precision Cvt  2023        0 Km      828.100      $
#
#                                                       URL        Marca  \
# 106539  https://auto.mercadolibre.com.ar/MLA-155915313...         Fiat
# 106540  https://auto.mercadolibre.com.ar/MLA-139487782...   Volkswagen
# 106541  https://auto.mercadolibre.com.ar/MLA-139482218...       Toyota
# 106542  https://auto.mercadolibre.com.ar/MLA-152365893...      Peugeot
# 106543  https://auto.mercadolibre.com.ar/MLA-152395469...      Peugeot
# ...                                                   ...          ...
# 106634  https://auto.mercadolibre.com.ar/MLA-139438614...   Volkswagen
# 106635  https://auto.mercadolibre.com.ar/MLA-136949933...       Toyota
# 106636  https://auto.mercadolibre.com.ar/MLA-155600699...  Lamborghini
# 106637  https://auto.mercadolibre.com.ar/MLA-155604834...         Ford
# 106638  https://auto.mercadolibre.com.ar/MLA-150581209...         Fiat
#
#          Modelo Motor Potencia
# 106539      500     0        0
# 106540   Amarok   2.0      140
# 106541    Etios   1.5        0
# 106542      208   1.6        0
# 106543      407   2.0        0
# ...         ...   ...      ...
# 106634   Amarok   2.0      180
# 106635    Yaris   1.5      107
# 106636  Huracán     0        0
# 106637   Ranger   2.3        0
# 106638   Cronos   1.3        0
#
# [100 rows x 10 columns]

# %%
autos = autos[['Marca', 'Modelo', 'Motor', 'Version', 'Potencia', 'Año', 'Kilometros', 'Precio', 'Moneda', 'URL']]

# %%
autos['Version'] = autos['Version'].str.replace('cv', '')
autos['Kilometros'] = autos['Kilometros'].str.replace(' Km', '')
autos['Kilometros'] = autos['Kilometros'].str.replace(' km', '')
autos['Kilometros'] = autos['Kilometros'].str.replace('Km', '')
autos['Kilometros'] = autos['Kilometros'].str.replace('km', '')

# %%
autos
# Out:
#               Marca   Modelo Motor                 Version Potencia   Año  \
# 0              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 1              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 2              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 3              Fiat   Cronos   1.3                Drive Mt        0  2023
# 4           Renault  Alaskan   2.3    t 16v Confort Mt 4x2        0  2023
# ...             ...      ...   ...                     ...      ...   ...
# 106634   Volkswagen   Amarok   2.0  Cd Tdi  Comfortline At      180  2023
# 106635       Toyota    Yaris   1.5                Xls Pack      107  2023
# 106636  Lamborghini  Huracán     0  Evo Spyder  Evo Spyder        0  2021
# 106637         Ford   Ranger   2.3          Cs F-truck 4x2        0  2008
# 106638         Fiat   Cronos   1.3           Precision Cvt        0  2023
#
#        Kilometros       Precio Moneda  \
# 0               0      510.000      $
# 1               0      450.000      $
# 2               0      350.000      $
# 3               0      480.000      $
# 4               0      400.000      $
# ...           ...          ...    ...
# 106634          0  201.000.000      $
# 106635          0  201.000.000      $
# 106636      3.000      710.000    U$S
# 106637      5.000  250.000.000      $
# 106638          0      828.100      $
#
#                                                       URL
# 0       https://auto.mercadolibre.com.ar/MLA-139577693...
# 1       https://auto.mercadolibre.com.ar/MLA-139560845...
# 2       https://auto.mercadolibre.com.ar/MLA-156229490...
# 3       https://auto.mercadolibre.com.ar/MLA-139471630...
# 4       https://auto.mercadolibre.com.ar/MLA-146794245...
# ...                                                   ...
# 106634  https://auto.mercadolibre.com.ar/MLA-139438614...
# 106635  https://auto.mercadolibre.com.ar/MLA-136949933...
# 106636  https://auto.mercadolibre.com.ar/MLA-155600699...
# 106637  https://auto.mercadolibre.com.ar/MLA-155604834...
# 106638  https://auto.mercadolibre.com.ar/MLA-150581209...
#
# [106626 rows x 10 columns]

# %%
autos = autos[autos['Precio'] != "111.111.111"]

# %%
autos['Precio'] = autos['Precio'].str.replace('.', '').astype(int)
autos['Kilometros'] = autos['Kilometros'].str.replace('.', '').astype(int)

# %%
autos
# Out:
#               Marca   Modelo Motor                 Version Potencia   Año  \
# 0              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 1              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 2              Fiat   Cronos   1.3               Drive Cvt        0  2023
# 3              Fiat   Cronos   1.3                Drive Mt        0  2023
# 4           Renault  Alaskan   2.3    t 16v Confort Mt 4x2        0  2023
# ...             ...      ...   ...                     ...      ...   ...
# 106634   Volkswagen   Amarok   2.0  Cd Tdi  Comfortline At      180  2023
# 106635       Toyota    Yaris   1.5                Xls Pack      107  2023
# 106636  Lamborghini  Huracán     0  Evo Spyder  Evo Spyder        0  2021
# 106637         Ford   Ranger   2.3          Cs F-truck 4x2        0  2008
# 106638         Fiat   Cronos   1.3           Precision Cvt        0  2023
#
#         Kilometros     Precio Moneda  \
# 0                0     510000      $
# 1                0     450000      $
# 2                0     350000      $
# 3                0     480000      $
# 4                0     400000      $
# ...            ...        ...    ...
# 106634           0  201000000      $
# 106635           0  201000000      $
# 106636        3000     710000    U$S
# 106637        5000  250000000      $
# 106638           0     828100      $
#
#                                                       URL
# 0       https://auto.mercadolibre.com.ar/MLA-139577693...
# 1       https://auto.mercadolibre.com.ar/MLA-139560845...
# 2       https://auto.mercadolibre.com.ar/MLA-156229490...
# 3       https://auto.mercadolibre.com.ar/MLA-139471630...
# 4       https://auto.mercadolibre.com.ar/MLA-146794245...
# ...                                                   ...
# 106634  https://auto.mercadolibre.com.ar/MLA-139438614...
# 106635  https://auto.mercadolibre.com.ar/MLA-136949933...
# 106636  https://auto.mercadolibre.com.ar/MLA-155600699...
# 106637  https://auto.mercadolibre.com.ar/MLA-155604834...
# 106638  https://auto.mercadolibre.com.ar/MLA-150581209...
#
# [106623 rows x 10 columns]

# %%
autos = autos[~((autos['Precio'] < 5000000) & (autos['Kilometros'] < 10000) & (autos['Moneda'] == '$'))]
autos = autos[~((autos['Precio'] < 5000) & (autos['Kilometros'] < 10000) & (autos['Moneda'] == 'U$S'))]
autos = autos[~((autos['Año'] < 2000) & (autos['Kilometros'] < 10000))]

# %%
autos.shape
# Out:
# (104624, 10)

# %%
autos.loc[autos['Moneda'] == '$', 'Precio'] /= 1000

# %%
autos.drop('Moneda', axis=1, inplace=True)
autos.drop('Potencia', axis=1, inplace=True) #Eliminar potencia !Recordar¡

# %%
autos.head()
# Out:
#       Marca    Modelo Motor  Version Potencia   Año  Kilometros  Precio  \
# 8      Ford    Mondeo   2.0  Ghia At        0  1996      260000  1500.0
# 11     Ford  Aerostar   3.0       V6        0  1998      100000   500.0
# 12    Smart   Forfour   1.0  Passion        0  2018       52000  1111.0
# 13  Jianshe      2017     0                 0  2017      220000  1000.0
# 26   Toyota     Hilux   3.0  Srv 4x2        0  2006      190000  1111.0
#
#                                                                                                                                                                                  URL
# 8           https://auto.mercadolibre.com.ar/MLA-1548451044-ford-mondeo-1996-20-ghia-at-_JM#position=9&search_layout=grid&type=item&tracking_id=8373f96e-c093-4008-afa2-3fddd7242e26
# 11                 https://auto.mercadolibre.com.ar/MLA-1394957667-ford-aerostar-v6-30-_JM#position=12&search_layout=grid&type=item&tracking_id=8373f96e-c093-4008-afa2-3fddd7242e26
# 12       https://auto.mercadolibre.com.ar/MLA-1558994524-smart-forfour-2018-10-passion-_JM#position=13&search_layout=grid&type=item&tracking_id=8373f96e-c093-4008-afa2-3fddd7242e26
# 13  https://auto.mercadolibre.com.ar/MLA-1543106396-fiat-palio-weekend-17-turbo-diesel-_JM#position=14&search_layout=grid&type=item&tracking_id=8373f96e-c093-4008-afa2-3fddd7242e26
# 26             https://auto.mercadolibre.com.ar/MLA-1394569893-toyota-hilux-30-srv-4x2-_JM#position=27&search_layout=grid&type=item&tracking_id=8373f96e-c093-4008-afa2-3fddd7242e26

# %%
autos.reset_index(drop=True, inplace=True)
autos.to_csv('autos.csv', index=False)

# %% [markdown]
# ## ROBOS

# %%
robos1 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202301.csv')
robos2 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202302.csv')
robos3 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202303.csv')
robos4 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202304.csv')
robos5 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202305.csv')
robos6 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202306.csv')
robos7 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202307.csv')
robos8 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202308.csv')
robos9 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202309.csv')
robos10 = pd.read_csv('Robos/dnrpa-robos-recuperos-autos-202310.csv')

# %%
robos = pd.concat([robos1, robos2, robos3, robos4, robos5, robos6, robos7, robos8, robos9, robos10], ignore_index=True)

# %%
robos['automotor_modelo_descripcion'] = robos['automotor_modelo_descripcion'].str.split().str[0]

# %%
robos = robos[['registro_seccional_descripcion', 'registro_seccional_provincia', 'automotor_anio_modelo', 'automotor_tipo_descripcion', 'automotor_marca_descripcion', 'automotor_modelo_descripcion']]

# %%
robos['automotor_anio_modelo'] = robos['automotor_anio_modelo'].fillna(0)
robos['automotor_anio_modelo'] = robos['automotor_anio_modelo'].astype(int)

# %%
robos['registro_seccional_descripcion'] = robos['registro_seccional_descripcion'].str.replace(r'\b\d+\s*$', '', regex=True)
robos['registro_seccional_descripcion'] = robos['registro_seccional_descripcion'].str.replace(r'\s*N[°º]?\s*$', '', regex=True)

# %%
robos = robos.rename(columns={'registro_seccional_descripcion':'Localidad','registro_seccional_provincia':'Provincia','automotor_anio_modelo':'Auto_Año','automotor_tipo_descripcion':'Tipo_de_Auto','automotor_marca_descripcion':'Marca'
,'automotor_modelo_descripcion':'Modelo'})

# %%
robos['Marca'] = robos['Marca'].str.capitalize()
robos['Localidad'] = robos['Localidad'].str.capitalize()
robos['Tipo_de_auto'] = robos['Tipo_de_auto'].str.capitalize()
robos['Modelo'] = robos['Modelo'].str.capitalize()

# %%
robos
# Out:
#                 Localidad                  Provincia  Auto_año  \
# 0                   Moron               Buenos Aires      1999
# 1                   Tigre               Buenos Aires      1998
# 2                   Moron               Buenos Aires      1999
# 3                 Mendoza                    Mendoza      2002
# 4                 Rosario                   Santa Fe      1999
# ...                   ...                        ...       ...
# 38939             Adrogue               Buenos Aires      2000
# 38940     Capital federal  Ciudad Autónoma de Bs.As.      1994
# 38941             Mendoza                    Mendoza      1996
# 38942          La matanza               Buenos Aires      1996
# 38943  San pedro de jujuy                      Jujuy      2004
#
#                Tipo_de_auto          Marca       Modelo
# 0                   S.wagon      Chevrolet        Corsa
# 1      Furgon vidriado c/as     Volkswagen  Transporter
# 2            Berlina 3 ptas        Renault         Clio
# 3           Berlina 4 ptas.        Renault       Megane
# 4                     Sedan      Chevrolet        Corsa
# ...                     ...            ...          ...
# 38939          Sedan 3 ptas     Volkswagen          Gol
# 38940          Sedan 2 ptas        Peugeot          205
# 38941  Transp. de pasajeros           Ford      Transit
# 38942               Pick up     Volkswagen           Vw
# 38943  Tractor de carretera  Mercedes benz      Ls-1634
#
# [38944 rows x 6 columns]

# %%
robos.reset_index(drop=True, inplace=True)
robos.to_csv('robos.csv', index=False)

# %% [markdown]
# ## Seguridad

# %%
seguridad = pd.read_csv('seguridad.csv', sep=';', encoding='latin-1')

# %%
seguridad = seguridad[['COMPANY ', 'MODEL ', 'STYLE', 'YEAR', 'DOORS', 'AIRBAGS', 'ADULT ', 'CHILD', 'LATIN NCA']]

# %%
seguridad = seguridad.rename(columns={'COMPANY ':'Marca','MODEL ':'Modelo','STYLE':'Cuerpo','YEAR':'Año','DOORS':'Puertas','ADULT ':'Adulto','CHILD':'Niños', 'AIRBAGS':'Airbags'})

# %%
seguridad['Marca'] = seguridad['Marca'].str.capitalize()
seguridad['Cuerpo'] = seguridad['Cuerpo'].str.upper()
seguridad['Modelo'] = seguridad['Modelo'].str.capitalize()

# %%
seguridad.dropna(inplace=True)

# %%
seguridad['Año'] = seguridad['Año'].astype(int)

# %%
seguridad
# Out:
#            Marca      Modelo     Cuerpo   Año  Puertas Airbags  Adulto  Niños  \
# 0      Chevrolet     tracker        SUV  2020      5.0      6     91.0   92.0
# 1        Citroen         c3         SUV  2023      5.0       2    31.0   12.0
# 2            Byd          f0         HB  2016      5.0       0    10.0   26.0
# 3           Fiat  Strada 700  PICK UP 4  2022      4.0       4    41.0   53.0
# 4           Fiat  Strada 700  PICK UP 2  2022      2.0       2    47.0   22.0
# ..           ...         ...        ...   ...      ...     ...     ...    ...
# 133  Volkswagen      Virtus      SEDAN   2018      4.0       4    96.0   88.0
# 134  Volkswagen        Polo         HB   2017      5.0       4    95.0   88.0
# 135  Volkswagen     Golf vii        HB   2017      5.0       5    98.0   89.0
# 136  Volkswagen     Golf vii        HB   2017      5.0       5    98.0   89.0
# 137  Volkswagen     Golf vii        HB   2017      5.0       5    98.0   89.0
#
#      LATIN NCA
# 0          5.0
# 1          0.0
# 2          0.0
# 3          1.0
# 4          1.0
# ..         ...
# 133        5.0
# 134        5.0
# 135        5.0
# 136        5.0
# 137        5.0
#
# [138 rows x 9 columns]

# %%
seguridad.reset_index(drop=True, inplace=True)
seguridad.to_csv('seguridad.csv', index=False)
